# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data=pd.read_csv('diabetes_model.csv')
data1=pd.DataFrame(data)

# %%
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %%
data1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            5       77             82             41       42  35.8
# 1            9      122             56              0        0  33.3
# 2            0      113             76              0        0  33.3
# 3            1      139             62             41      480  40.7
# 4           10      161             68             23      132  25.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.156   35        0
# 1                     1.114   33        1
# 2                     0.278   23        1
# 3                     0.536   21        0
# 4                     0.326   47        1

# %%
data1.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# # 1. Create a countplot of Outcome

# %%
sns.countplot(x='Outcome',data=data1)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %% [markdown]
# # 2. Analyse the effect of age on Outcome using Boxplot

# %%
sns.boxplot(x='Outcome',y='Age',data=data1)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Age'>

# %% [markdown]
# # 3. Check for the chances of getting diabetes if it is commom in family,using the Diabetes Pedigree Function

# %%
 sns.stripplot(x=data['Outcome'],y=data['DiabetesPedigreeFunction'],data=data1)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='DiabetesPedigreeFunction'>

# %% [markdown]
# # 4. Check for the relationship with Insulin and Glucose and group the datapoints by Outcome

# %%
import matplotlib.pyplot as plt

# %%
sns.scatterplot(x=data['Insulin'],y=data['Glucose'],data=data1,hue=data['Outcome'])
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Glucose'>

# %% [markdown]
# # 5. Create a heatmap on Correlation of features in the data

# %%
sns.heatmap(data.corr(),annot=True)
plt.xticks(rotation=90)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5]),
#  [Text(0.5, 0, 'Pregnancies'),
#   Text(1.5, 0, 'Glucose'),
#   Text(2.5, 0, 'BloodPressure'),
#   Text(3.5, 0, 'SkinThickness'),
#   Text(4.5, 0, 'Insulin'),
#   Text(5.5, 0, 'BMI'),
#   Text(6.5, 0, 'DiabetesPedigreeFunction'),
#   Text(7.5, 0, 'Age'),
#   Text(8.5, 0, 'Outcome')])
